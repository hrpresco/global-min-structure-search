# %%
import pandas as pd
import tensorflow as tf
import tempfile
import os
import numpy as np
import mayavi as maya
from Determine_Bonds_Get_Input import take_data_batch
# Out:
# features {
#   feature {
#     key: "label"
#     value {
#       float_list {
#         value: 0.244
#       }
#     }
#   }
#   feature {
#     key: "features"
#     value {
#       float_list {
#         value: 0
#         value: 3.75
#         value: 8
#         value: 0.097
#         value: 0.055
#         value: 498
#         value: 4.62
#         value: 2.91
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "label"
#     value {
#       float_list {
#         value: 3.15
#       }
#     }
#   }
#   feature {
#     key: "features"
#     value {
#       float_list {
#         value: 2.5
#         value: 2.99
#         value: 57
#         value: 0.068
#         value: -0.19
#         value: 1.18
#         value: 10.98
#         value: 2.8
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "label"
#     value {
#       float_list {
#         value: 0.88
#       }
#     }
#   }
#   feature {
#     key: "features"
#     value {
# ...
